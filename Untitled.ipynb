# %%
import pandas as pd

df = "COVID-19 Cases.csv"
pd.set_option('display.max_columns', None)
covid_data = pd.read_csv(df, low_memory=False)

# %%
covid_data.head()
# Out:
#    Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0  Confirmed                        NaN      0           0   2/3/2020
# 1     Deaths                        NaN      0           0   3/1/2020
# 2  Confirmed                        NaN     23           0  4/21/2020
# 3     Deaths                        NaN      0           0  2/11/2020
# 4  Confirmed                        NaN      0           0   2/6/2020
#
#           Combined_Key       Country_Region Province_State Admin2 iso2 iso3  \
# 0          Switzerland          Switzerland            NaN    NaN   CH  CHE
# 1               Cyprus               Cyprus            NaN    NaN   CY  CYP
# 2  Antigua and Barbuda  Antigua and Barbuda            NaN    NaN   AG  ATG
# 3              Jamaica              Jamaica            NaN    NaN   JM  JAM
# 4               Belize               Belize            NaN    NaN   BZ  BLZ
#
#    FIPS      Lat     Long  Population_Count  \
# ...

# %%
list(covid_data)
# Out:
# ['Case_Type',
#  'People_Total_Tested_Count',
#  'Cases',
#  'Difference',
#  'Date',
#  'Combined_Key',
#  'Country_Region',
#  'Province_State',
#  'Admin2',
#  'iso2',
#  'iso3',
#  'FIPS',
#  'Lat',
#  'Long',
#  'Population_Count',
#  'People_Hospitalized_Cumulative_Count',
#  'Data_Source',
#  'Prep_Flow_Runtime']

# %%
#remove unwanted columns
conf_states = covid_data[['Case_Type', 'Date', 'Cases', 'Population_Count', 'People_Total_Tested_Count', 'People_Hospitalized_Cumulative_Count','Province_State','Admin2', 'Country_Region']]
conf_states.head()
# Out:
#    Case_Type       Date  Cases  Population_Count  People_Total_Tested_Count  \
# 0  Confirmed   2/3/2020      0         8654618.0                        NaN
# 1     Deaths   3/1/2020      0         1207361.0                        NaN
# 2  Confirmed  4/21/2020     23           97928.0                        NaN
# 3     Deaths  2/11/2020      0         2961161.0                        NaN
# 4  Confirmed   2/6/2020      0          397621.0                        NaN
#
#    People_Hospitalized_Cumulative_Count Province_State Admin2  \
# 0                                   NaN            NaN    NaN
# 1                                   NaN            NaN    NaN
# 2                                   NaN            NaN    NaN
# 3                                   NaN            NaN    NaN
# 4                                   NaN            NaN    NaN
#
#         Country_Region
# 0          Switzerland
# 1               Cyprus
# 2  Antigua and Barbuda
# 3              Jamaica
# ...

# %%
list(conf_states)
# Out:
# ['Case_Type',
#  'Date',
#  'Cases',
#  'Population_Count',
#  'People_Total_Tested_Count',
#  'People_Hospitalized_Cumulative_Count',
#  'Province_State',
#  'Admin2',
#  'Country_Region']
